# %% [markdown]
# ___
#
#
#
# ## <p style="background-color:#FDFEFE; font-family:Arial; color:#47AC34; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:Arial; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:Arial; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:Arial; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#47AC34; font-family:Georgia; color:#FFFFFF; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:Georgia; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:#FFF9ED; background-color:#47AC34" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:20b2aa; background-color:#47AC34" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:Georgia; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:white; background-color:#47AC34" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df = pd.read_csv("adult.csv")

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:Georgia; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:white; background-color:#47AC34" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
# Your Code is Here

df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# Your Code is Here

df.shape
# Out:
# (32561, 15)

# %%
# Your Code is Here

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
# Check if the Dataset have any Duplicate

# Your Code is Here
df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %% [raw]
# Desired Output:
#
# False    32537
# True        24
# dtype: int64

# %%
# Drop Duplicates

# Your Code is Here

df.drop_duplicates(inplace = True)

# %%
# Check the shape of the Dataset

# Your Code is Here

df.shape
# Out:
# (32537, 15)

# %%
# Your Code is Here

df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %% [markdown]
# **Rename the features of;**<br>
# **``"education-num"``**, **``"marital-status"``**, **``"capital-gain"``**, **``"capital-loss"``**, **``"hours-per-week"``**, **``"native-country"``** **as**<br>
# **``"education_num"``**, **``"marital_status"``**, **``"capital_gain"``**, **``"capital_loss"``**, **``"hours_per_week"``**, **``"native_country"``**, **respectively and permanently.**

# %%
# Your Code is Here
df.rename(columns = {"education-num":"education_num","marital-status":"marital_status","capital-loss":"capital_loss",
                    "hours-per-week":"hours_per_week", "native-country":"native_country"}, inplace = True)

# %%
# Check the sum of Missing Values per column

# Your Code is Here
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital-gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# Check the Percentage of Missing Values

# Your Code is Here
(df.isnull().sum()/len(df))*100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# sex               0.000
# capital-gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
# Your Code is Here
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
# Your Code is Here

df.select_dtypes(include='object').describe().T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %% [markdown]
# **Assign the Columns (Features) of object data type as** **``"object_col"``**

# %%
# Your Code is Here

object_col = df.select_dtypes(include="object").columns

# %%
object_col
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'salary'],
#       dtype='object')

# %%
for col in object_col:
    print(col)
    print("--"*8)
    print(df[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ----------------------------------------
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ----------------------------------------
# marital_status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# ...

# %% [markdown]
# **Check if the Dataset has any Question Mark** **``"?"``**

# %%
# Your Code is Here
df[df.isin(["?"])].any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital-gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:georgia; color:white; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:white; background-color:#47AC34" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## Salary (Target Feature)

# %% [markdown]
# **Check the count of person in each "salary" levels and visualize it with a countplot**

# %%
# Your Code is Here

df.salary.value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.countplot(df.salary);

# %% [markdown]
# **Check the percentage of person in each "salary" levels and visualize it with a pieplot**

# %%
# Your Code is Here

df.salary.value_counts(normalize = True)
# Out:
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %%
# Your Code is Here
plt.pie(df.salary.value_counts(normalize = True),autopct='%1.1f%%',
        shadow=True, startangle=0, explode = (0, 0.1), labels = ("<=50K",">50K"));

plt.title("percentage of Income-Levels");

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ## age

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(x = df.age);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.histplot(data=df.age, bins = 20, kde = True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.age.describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(x = df.salary, y= df.age, hue_order = df.salary.value_counts(), data = df);

# %%
df.salary.unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
# Your Code is Here

sns.histplot(data = df, x = df.age, hue = df.salary, bins= 20, kde = True, legend = True);

# %%
# Your Code is Here

sns.kdeplot(data=df, x=df.age, hue= df.salary, shade = True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary")["age"].describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# ## fnlwgt

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(x = df.fnlwgt);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(data = df.fnlwgt, shade=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.fnlwgt.describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(data = df, x= df.salary, y = df.fnlwgt);

# %%
# Your Code is Here

sns.kdeplot(data = df, x= df.fnlwgt,hue = df.salary, shade= True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary")["fnlwgt"].describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# ## capital_gain

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# Your Code is Here

sns.boxplot(x=df["capital-gain"]);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(data = df, x=df["capital-gain"], shade=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df["capital-gain"].describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital-gain, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
sns.boxplot(data=df, x= df.salary, y=df["capital-gain"]);

# %%
# Your Code is Here

sns.kdeplot(data = df, x= df["capital-gain"], hue= df.salary, shade = True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary")["capital-gain"].describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_gain not equal the zero**

# %%
df[df["capital-gain"]!=0].groupby("salary").describe()["capital-gain"]
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %%
# Your Code is Here
df[df["capital-gain"]!=0].groupby("salary").describe()["capital-gain"]
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# ## capital_loss

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here
sns.boxplot(data = df, x = "capital_loss");

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
sns.kdeplot(data=df, x="capital_loss", shade=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here
df.capital_loss.describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
sns.boxplot(data=df, y = "capital_loss", x = "salary");

# %%
# Your Code is Here
sns.kdeplot(data=df, x = "capital_loss", hue = "salary", shade = True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here
df.groupby("salary")["capital_loss"].describe()
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_loss not equel the zero**

# %%
# Your Code is Here
df[df["capital_loss"]!=0].groupby("salary").describe()["capital_loss"]
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ..................

# %% [markdown]
# ## hours_per_week

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here
sns.boxplot(data=df, x = "hours_per_week");

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
sns.kdeplot(data=df, x = "hours_per_week", shade=True)
plt.show()

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here
df.hours_per_week.describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
sns.boxplot(data = df, x= "salary", y ="hours_per_week");

# %%
# Your Code is Here
sns.kdeplot(data=df, x="hours_per_week", shade=True, hue= "salary")
plt.show()

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here
df.groupby("salary")["hours_per_week"].describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# ### See the relationship between each numeric features by target feature (salary) in one plot basically

# %%
# Your Code is Here
sns.pairplot(data=df, hue="salary", palette="viridis", corner=True);

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ## education & education_num

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here
df.education.value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
# Your Code is Here
df["education_num"].value_counts()
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
# Your Code is Here
df.groupby("education")["education_num"].value_counts(dropna=False) # "dropna=False" NaN değerleri de göstermesi için.
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# ...

# %% [markdown]
# **Visualize the count of person in each categories for these features (education, education_num) separately**

# %%
# Your Code is Here
plt.xticks(rotation = "vertical") # etiketleri dikey yazmak için.
sns.countplot(x= df.education);

# %%
# Your Code is Here
sns.countplot(x= df.education_num);

# %% [markdown]
# **Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot**

# %%
# Your Code is Here
df.groupby("education")["salary"].value_counts()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# ...

# %%
# Your Code is Here
plt.xticks(rotation = "vertical")
sns.countplot(x= df.education, hue = df.salary);

# %%
# Your Code is Here
df.groupby("education_num")["salary"].value_counts()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
# ...

# %%
# Your Code is Here
plt.xticks(rotation = "vertical")
sns.countplot(x= df.education_num, hue = df.salary);

# %% [markdown]
# **Visualize the boxplot of "education_num" feature by "salary" levels**

# %%
# Your Code is Here
sns.boxplot(data=df, y= "education_num", x="salary");

# %% [markdown]
# **Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.**

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
# Your Code is Here
df["education"].apply(lambda x: mapping_education(x)).value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %%
# By using "mapping_education" def function above, create a new column named "education_summary"

# Your Code is Here
df["education_summary"] = df["education"].apply(lambda x: mapping_education(x))

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# **Visualize the count of person in each categories for these new education levels (high, medium, low)**

# %%
# Your Code is Here
sns.countplot(data = df, x= "education_summary");

# %% [markdown]
# **Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("education_summary")["salary"].value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.countplot(x=df["education_summary"], hue = df.salary);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby("education_summary")["salary"].value_counts(normalize=True)
# Out:
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
df.groupby(df[df["education_summary"]=="low_level_grade"]["education_summary"])["salary"].value_counts()
# Out:
# education_summary  salary
# low_level_grade    <=50K     4004
#                    >50K       244
# Name: salary, dtype: int64

# %%
# Your Code is Here
fig,ax = plt.subplots(1,3, figsize= (15,15))

ax[0].set_title("high_level_grade")
ax[0].pie(df.groupby(df[df["education_summary"]=="high_level_grade"]["education_summary"])["salary"].value_counts(), labels =df.salary.unique(), autopct='%2.2f%%');

ax[1].set_title("low_level_grade")
ax[1].pie(df.groupby(df[df["education_summary"]=="low_level_grade"]["education_summary"])["salary"].value_counts(), labels =df.salary.unique(), autopct='%2.2f%%');

ax[2].set_title("medium_level_grade")
ax[2].pie(df.groupby(df[df["education_summary"]=="medium_level_grade"]["education_summary"])["salary"].value_counts(), labels =df.salary.unique(), autopct='%2.2f%%');

# %% [markdown]
# **Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["education_summary"].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
# Your Code is Here
sns.countplot(data=df, x= "salary", hue = "education_summary");

# %% [markdown]
# **Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby("salary")["education_summary"].value_counts(normalize=True)
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
df.groupby(df[df["salary"]=="<=50K"]["education_summary"])["salary"].value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
# low_level_grade     <=50K      4004
# medium_level_grade  <=50K     16539
# Name: salary, dtype: int64

# %%
# Your Code is Here
fig,ax = plt.subplots(1,2, figsize= (15,15))

ax[0].set_title("<=50K")
ax[0].pie(df.groupby(df[df["salary"]=="<=50K"]["education_summary"])["salary"].value_counts(), labels =df.education_summary.unique(), autopct='%2.2f%%');

ax[1].set_title(">50K")
ax[1].pie(df[df["salary"]==">50K"]["education_summary"].value_counts(), labels =df.education_summary.unique(), autopct='%2.2f%%');

# %%
null_values = df.isnull().sum()
null_values = pd.DataFrame(null_values,columns=['null'])
j=1
sum_total=len(df)
null_values['percentage'] = null_values['null']/sum_total
round(null_values*100,3).sort_values('percentage',ascending=False)
# Out:
#                      null  percentage
# relationship       506400      15.564
# education_num       80200       2.465
# age                     0       0.000
# workclass               0       0.000
# fnlwgt                  0       0.000
# education               0       0.000
# marital_status          0       0.000
# occupation              0       0.000
# race                    0       0.000
# sex                     0       0.000
# capital-gain            0       0.000
# capital_loss            0       0.000
# hours_per_week          0       0.000
# native_country          0       0.000
# salary                  0       0.000
# education_summary       0       0.000

# %%
ser = df.groupby("salary")["education_summary"].value_counts() / (df.groupby("salary")["education_summary"]).count()

# %%
ser1 = ser.first_valid_index

# %%
ser.reindex()
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
 # df1 = pd.DataFrame(ser.factorize(), columns = ["salary","education_summary","percentage"], index = [range(6)])
 df1 = pd.DataFrame(ser)

# %%
df1
# Out:
#                            education_summary
# salary education_summary
# <=50K  medium_level_grade              0.670
#        high_level_grade                0.168
#        low_level_grade                 0.162
# >50K   high_level_grade                0.499
#        medium_level_grade              0.470
#        low_level_grade                 0.031

# %%
# Your Code is Here
pd.DataFrame(df.groupby("salary")["education_summary"].value_counts(normalize=True) )
# Out:
#                            education_summary
# salary education_summary
# <=50K  medium_level_grade              0.670
#        high_level_grade                0.168
#        low_level_grade                 0.162
# >50K   high_level_grade                0.499
#        medium_level_grade              0.470
#        low_level_grade                 0.031

# %%
df["education_summary"]=df["education_summary"].replace({"high_level_grade":"hight","medium_level_grade":"medium","low_level_grade":"low"})

# %%
# Your Code is Here
fig,ax = plt.subplots(1,2, figsize= (15,15))

ax[0].set_title("<=50K")
ax[0].pie(df.groupby(df[df["salary"]=="<=50K"]["education_summary"])["salary"].value_counts(), labels =df.education_summary.unique(), autopct='%2.2f%%');

ax[1].set_title(">50K")
ax[1].pie(df[df["salary"]==">50K"]["education_summary"].value_counts(), labels =df.education_summary.unique(), autopct='%2.2f%%');

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ......................

# %% [markdown]
# ## marital_status & relationship

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

df.marital_status.value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
# Your Code is Here
df.relationship.value_counts()
# Out:
# Husband           13187
# Not-in-family      8292
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Fill missing values with "Unknown" in the column of "relationship"

# Your Code is Here
df.relationship.replace(np.nan,"unknown", inplace =True)
df.relationship.isnull().sum()
# Out:
# 0

# %%
# Your Code is Here
df.groupby("relationship")["marital_status"].value_counts()
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
# ...

# %% [markdown]
# **Assessment :** ........

# %% [markdown]
# **Visualize the count of person in each categories**

# %%
# Your Code is Here
plt.xticks(rotation = "vertical")
sns.countplot(data = df, x= "marital_status");

# %% [markdown]
# **Check the count of person in each "salary" levels by categories and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("marital_status")["salary"].value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.xticks(rotation = "vertical")
sns.countplot(data = df, x= "marital_status", hue = "salary");

# %% [markdown]
# **Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
#df["marital_status"] = df["marital_status"].apply(lambda x: mapping_marital_status(x))

# %%
# Your Code is Here
df.marital_status.value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
# By using "mapping_marital_status" def function above, create a new column named "marital_status_summary"

# Your Code is Here
df["marital_status_summary"] = df["marital_status"].apply(lambda x: mapping_marital_status(x))

# %% [markdown]
# **Visualize the count of person in each categories for these new marital status (married, unmarried)**

# %%
# Your Code is Here

sns.countplot(data =df, x="marital_status");

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/wRjj6Bx/49.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("marital_status_summary")["salary"].value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.countplot(x=df.marital_status_summary, hue= df.salary);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby("marital_status_summary")["salary"].value_counts(normalize=True)
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
df.groupby(df[df["marital_status_summary"]=="married"]["marital_status_summary"])["salary"].value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K     8677
#                         >50K      6734
# Name: salary, dtype: int64

# %%
# Your Code is Here
fig,ax = plt.subplots(1,2)
ax[0].set_title("married")
ax[0].pie(df.groupby(df[df["marital_status_summary"]=="married"]["marital_status_summary"])["salary"].value_counts(), labels = df.salary.unique(),  autopct = "%2.2f");

ax[1].set_title("unmarried")
ax[1].pie(df.groupby(df[df["marital_status_summary"]=="unmarried"]["marital_status_summary"])["salary"].value_counts(), labels = df.salary.unique(), shadow = True, autopct = "%2.2f");

# %% [markdown]
# **Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["marital_status_summary"].value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
# Your Code is Here
sns.countplot(df.salary, hue = df.marital_status_summary);

# %% [markdown]
# **Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
# Your Code is Here
df.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Swb4rb7/v53.png)

# %%
# Your Code is Here
fig,ax = plt.subplots(1,2, figsize= (15,15))

ax[0].set_title("<=50K")
ax[0].pie(df.groupby(df[df["salary"]=="<=50K"]["marital_status_summary"])["salary"].value_counts(), labels =df.marital_status_summary.unique(), autopct='%2.2f%%');

ax[1].set_title(">50K")
ax[1].pie(df.groupby(df[df["salary"]==">50K"]["marital_status_summary"])["salary"].value_counts(), labels =df.marital_status_summary.unique(), autopct='%2.2f%%');

# %% [markdown]
# ## workclass

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here
df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here
plt.xticks(rotation= "vertical")
sns.countplot(x=df.workclass);

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unkown"

# Your Code is Here
df.workclass.replace("?","Unknown", inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by workclass groups and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("workclass")["salary"].value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.xticks(rotation="vertical")
sns.countplot(x=df.workclass, hue= df.salary);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot**

# %%
# Your Code is Here
df.groupby("workclass")["salary"].value_counts(normalize=True)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
# Your Code is Here
pd.DataFrame(df.groupby("workclass")["salary"].value_counts(normalize=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2980/1864620936.py in <module>
#       1 # Your Code is Here
# ----> 2 pd.DataFrame(df.groupby("workclass")["salary"].value_counts(normalize=True))
#
# NameError: name 'pd' is not defined

# %%
df.groupby("workclass")["salary"].unique()
# Out:
# workclass
# Federal-gov         [<=50K, >50K]
# Local-gov           [>50K, <=50K]
# Never-worked              [<=50K]
# Private             [<=50K, >50K]
# Self-emp-inc        [<=50K, >50K]
# Self-emp-not-inc    [<=50K, >50K]
# State-gov           [<=50K, >50K]
# Unknown             [>50K, <=50K]
# Without-pay               [<=50K]
# Name: salary, dtype: object

# %%
df.workclass.unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', 'Unknown', 'Self-emp-inc', 'Without-pay',
#        'Never-worked'], dtype=object)

# %%
# Your Code is Here
plt.xticks(rotation = "vertical")
ax = sns.countplot(df.workclass, hue=df.salary, data = df);
for p in ax.patches:
    ax.annotate(round(p.get_height() / df.workclass.count(), 2), (p.get_x(), p.get_height()));

# %% [markdown]
# **Check the count of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["workclass"].value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
# Your Code is Here
sns.countplot(x= df.salary, hue = df.workclass, data=df);

# %% [markdown]
# **Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby("salary")["workclass"].value_counts(normalize=True)
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
# Your Code is Here
pd.DataFrame(df.groupby("salary")["workclass"].value_counts(normalize=True)).set_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4308/439378531.py in <module>
#       1 # Your Code is Here
# ----> 2 pd.DataFrame(df.groupby("salary")["workclass"].value_counts(normalize=True)).set_index()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: set_index() missing 1 required positional argument: 'keys'

# %%
df1.rename(columns = {"workclass":"percentage"},inplace=True)
df1

# %%
df.percentage

# %%
# Your Code is Here
ax = sns.countplot(df.salary, hue = df.workclass);
for p in ax.patches:
    ax.annotate(round(p.get_height() / df.salary.count(), 2), (p.get_x(), p.get_height())); # değerleri üzerine yazmak

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Kz5BDBj/61.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ..................

# %% [markdown]
# ## occupation

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here
df.occupation.value_counts()

# %%
# Your Code is Here
plt.xticks(rotation ="vertical")
sns.countplot(df.occupation);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/F3qqLjS/62.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here
df.occupation.replace({"?":"Unknown"}, inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by occupation groups and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("occupation")["salary"].value_counts()

# %%
# Your Code is Here
plt.xticks(rotation="vertical")
sns.countplot(df.occupation, hue =df.salary);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/RhkhQCW/63.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot**

# %%
# Your Code is Here
df.groupby("occupation")["salary"].value_counts(normalize=True)

# %%
# Your Code is Here

# %%
# Your Code is Here
plt.xticks(rotation = "vertical")
sns.barplot(x= df.occupation, y=df.groupby("occupation")["salary"].value_counts(normalize=True), hue_order = df.salary );
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Orhan Python\Mustafa Hoca Proje\Üzerinde çalışılan-EDA Project (Analyze US Citizens)-Student - Kopya.ipynb Hücre 239 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Orhan%20Python/Mustafa%20Hoca%20Proje/%C3%9Czerinde%20%C3%A7al%C4%B1%C5%9F%C4%B1lan-EDA%20Project%20%28Analyze%20US%20Citizens%29-Student%20-%20Kopya.ipynb#Z1010sZmlsZQ%3D%3D?line=0'>1</a> # Your Code is Here
# ----> <a href='vscode-notebook-cell:/d%3A/Orhan%20Python/Mustafa%20Hoca%20Proje/%C3%9Czerinde%20%C3%A7al%C4%B1%C5%9F%C4%B1lan-EDA%20Project%20%28Analyze%20US%20Citizens%29-Student%20-%20Kopya.ipynb#Z1010sZmlsZQ%3D%3D?line=1'>2</a> plt.xticks(rotation = "vertical")
# ...

# %% [markdown]
# **Check the count of person in each occupation groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["occupation"].value_counts()

# %%
# Your Code is Here
ax=sns.countplot(df.salary, hue = df.occupation);
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x(), p.get_height()));

# %% [markdown]
# **Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here
df.groupby("salary")["occupation"].value_counts(normalize=True)

# %%
df1 = pd.DataFrame(data=df.groupby("salary")["occupation"].value_counts(normalize=True))
df1.columns
# Out:
# Index(['occupation'], dtype='object')

# %%
df1.occupation
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         ?                   0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         ?                   0.024
#         Other-service       0.017
#         Farming-fishing     0.015
# ...

# %%
# Your Code is Here
salary_occupation = df.groupby("salary")["occupation"].value_counts(normalize=True)
salary_occupation_table = pd.DataFrame(salary_occupation)
salary_occupation_table
# Out:
#                           occupation
# salary occupation
# <=50K  Adm-clerical            0.132
#        Craft-repair            0.128
#        Other-service           0.128
#        Sales                   0.108
#        Prof-specialty          0.092
#        Exec-managerial         0.085
#        Machine-op-inspct       0.071
#        ?                       0.067
#        Handlers-cleaners       0.052
#        Transport-moving        0.052
#        Farming-fishing         0.036
#        Tech-support            0.026
#        Protective-serv         0.018
#        Priv-house-serv         0.006
#        Armed-Forces            0.000
# >50K   Exec-managerial         0.251
#        Prof-specialty          0.237
#        Sales                   0.125
#        Craft-repair            0.119
#        Adm-clerical            0.065
#        Transport-moving        0.041
#        Tech-support            0.036
#        Machine-op-inspct       0.032
#        Protective-serv         0.027
# ...

# %%
salary_occupation_table.rename(columns={"occupation":"percentage"},inplace=True)

# %%
salary_occupation_table.reset_index(level=[0,1],inplace=True)

# %%
salary_occupation_table.columns
# Out:
# Index(['salary', 'occupation', 'percentage'], dtype='object')

# %%
salary_occupation_table.sort_values(by=["salary","occupation"],inplace=True)

# %%
# Your Code is Here
fig,ax = plt.subplots(figsize=(18,6))
sns.barplot(x="salary",y="percentage",data=salary_occupation_table,hue="occupation")
for i in ax.containers:
    ax.bar_label(i,fmt="%.3f")

# %% [markdown]
# ## race

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here
df.race.value_counts()

# %%
# Your Code is Here
plt.xticks(rotation = "vertical")
sns.countplot(df.race);

# %% [markdown]
# **Check the count of person in each "salary" levels by races and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("race")["salary"].value_counts()

# %%
# Your Code is Here
plt.xticks(rotation = "vertical")
sns.countplot(df.race, hue=df.salary);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot**

# %%
# Your Code is Here

df.groupby("race")["salary"].value_counts(normalize=True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
# Your Code is Here
fig,ax = plt.subplots(2,3, figsize= (15,15))

ax[0,0].set_title("Amer-Indian-Eskimo")
ax[0,0].pie(df.groupby(df[df["race"]=="Amer-Indian-Eskimo"]["race"])["salary"].value_counts(), labels =df.salary.unique(), autopct='%2.2f%%');

ax[0,1].set_title("Asian-Pac-Islander")
ax[0,1].pie(df.groupby(df[df["race"]=="Asian-Pac-Islander"]["race"])["salary"].value_counts(), labels =df.salary.unique(), autopct='%2.2f%%');

ax[0,2].set_title("Black")
ax[0,2].pie(df.groupby(df[df["race"]=="Black"]["race"])["salary"].value_counts(), labels =df.salary.unique(), autopct='%2.2f%%');

ax[1,0].set_title("Other")
ax[1,0].pie(df.groupby(df[df["race"]=="Other"]["race"])["salary"].value_counts(), labels =df.salary.unique(), autopct='%2.2f%%');

ax[1,1].set_title("White")
ax[1,1].pie(df.groupby(df[df["race"]=="White"]["race"])["salary"].value_counts(), labels =df.salary.unique(), autopct='%2.2f%%');

# %% [markdown]
# **Check the count of person in each races by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["race"].value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
# Your Code is Here
sns.countplot(df.salary, hue= df.race);

# %% [markdown]
# **Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here




df.groupby("salary")["race"].value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
# Your Code is Here
df.groupby("salary")["race"].value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
# Your Code is Here
fig,ax=plt.subplots(figsize=(12,6))
sns.countplot(x="salary",data=df,hue="race");

# %% [markdown]
# ## gender

# %% [markdown]
# **Check the count of person in each gender and visualize it with countplot**

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# Your Code is Here
df.sex.value_counts()
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %%
# Your Code is Here
sns.countplot(df.sex);

# %% [markdown]
# **Check the count of person in each "salary" levels by gender and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("sex")["salary"].value_counts()
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(df.sex, hue= df.salary);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot**

# %%
# Your Code is Here
df.groupby("sex")["salary"].value_counts(normalize=True)
# Out:
# sex     salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
# Your Code is Here
fig,ax = plt.subplots(1,2, figsize= (18,18))
colors = ["pink","orange"]
ax[0].set_title("Female")
ax[0].pie(df.groupby(df[df["sex"]=="Female"]["sex"])["salary"].value_counts(), labels =df.salary.unique(), autopct='%2.2f%%');

ax[1].set_title("Male")
ax[1].pie(df.groupby(df[df["sex"]=="Male"]["sex"])["salary"].value_counts(), labels =df.salary.unique(), autopct='%2.2f%%');

# %% [markdown]
# **Check the count of person in each gender by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["sex"].value_counts()
# Out:
# salary  sex
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: sex, dtype: int64

# %%
# Your Code is Here
sns.countplot(df.salary, hue= df.sex);

# %% [markdown]
# **Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot**

# %%
# Your Code is Here
df.groupby("salary")["sex"].value_counts(normalize=True)
# Out:
# salary  sex
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: sex, dtype: float64

# %%
# Your Code is Here
fig, ax = plt.subplots(1,2, figsize =( 15,15))

ax[0].set_title("<=50K")
ax[0].pie(df.groupby(df[df["salary"]== "<=50K"]["salary"])["sex"].value_counts(), labels = df.sex.unique(),autopct='%2.2f%%');

ax[1].set_title(">50K")
ax[1].pie(df.groupby(df[df["salary"]== ">50K"]["salary"])["sex"].value_counts(), labels = df.sex.unique(),autopct='%2.2f%%');

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ..............

# %% [markdown]
# ## native_country

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here
df.native_country.value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
# Your Code is Here
plt.xticks(rotation="vertical")
sns.countplot(df.native_country);

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here
df.native_country.replace({"?":"Unknown"})
# Out:
# 0        United-States
# 1        United-States
# 2        United-States
# 3        United-States
# 4                 Cuba
#              ...
# 32556    United-States
# 32557    United-States
# 32558    United-States
# 32559    United-States
# 32560    United-States
# Name: native_country, Length: 32537, dtype: object

# %% [markdown]
# **Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data**

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
# Your Code is Here
df.native_country.apply(lambda x: mapping_native_country(x)).value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
# By using "mapping_native_country" def function above, create a new column named "native_country_summary"

# Your Code is Here
df["native_country_summary"] = df.native_country.apply(lambda x: mapping_native_country(x))
df["native_country_summary"]
# Out:
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each new categories (US, Others)**

# %%
# Your Code is Here
sns.countplot(df["native_country_summary"] );

# %% [markdown]
# **Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot**

# %%
# Your Code is Here
df.groupby(df["native_country_summary"])["salary"].value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.countplot(df["native_country_summary"],  hue = df.salary);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby(df["native_country_summary"] )["salary"].value_counts(normalize=True)
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
# Your Code is Here
fig,ax = plt.subplots(1,2, figsize =(15,15))
ax[0].set_title("Others")
ax[0].pie(df.groupby(df[df["native_country_summary"]== "Others" ]["native_country_summary"])["salary"].value_counts(),labels=df.salary.unique(), autopct="%2.2F%%");

ax[1].set_title("US")
ax[1].pie(df.groupby(df[df["native_country_summary"]== "US" ]["native_country_summary"])["salary"].value_counts(),labels=df.salary.unique(), autopct="%2.2F%%");

# %% [markdown]
# **Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby("salary")["native_country_summary"].value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
# Your Code is Here
sns.countplot(df.salary, hue = df.native_country_summary);

# %% [markdown]
# **Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here
df.groupby("salary")["native_country_summary"].value_counts(normalize=True)
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
# Your Code is Here
fig,ax = plt.subplots(1,2, figsize =(15,15))
ax[0].set_title("<=50K")
ax[0].pie(df.groupby(df[df["salary"]== "<=50K" ]["salary"])["native_country_summary"].value_counts(),labels=df.native_country_summary.unique(), autopct="%2.2F%%");

ax[1].set_title(">50K")
ax[1].pie(df.groupby(df[df["salary"]== ">50K" ]["salary"])["native_country_summary"].value_counts(),labels=df.native_country_summary.unique(), autopct="%2.2F%%");

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** .................

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:white; background-color:#47AC34" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
# Your Code is Here
df.groupby(["salary","sex"])["age"].mean()
# Out:
# salary  sex
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
# Your Code is Here
plt.xticks(rotation="vertical")
ax = df.groupby(["salary","sex"])["age"].mean().plot(kind ="bar");
for p in ax.patches:
    ax.annotate((round(p.get_height())),(p.get_x()+0.2,p.get_height()));

# %%
# Your Code is Here
df.groupby(["salary","sex"])["age"].mean()
# Out:
# salary  sex
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
# Your Code is Here
ax=sns.barplot( data=df, x= df.salary, y= df.age,  hue= df.sex);
for p in ax.patches:
    ax.annotate((round(p.get_height())),(p.get_x()+0.2,p.get_height()));

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# Your Code is Here
US_upper_50K = df.loc[(df.native_country == "United-States")& (df.salary== ">50K")]

# %%
US_upper_50K.workclass.value_counts(normalize=True)*100
# Out:
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# ?                   2.455
# Name: workclass, dtype: float64

# %%
US_upper_50K_percentage = US_upper_50K.workclass.value_counts(normalize=True)*100

# %%
# Your Code is Here

fig,ax = plt.subplots(figsize=(12,6))
sns.barplot(x=US_upper_50K_percentage.index, y=US_upper_50K_percentage.values)

for i in ax.containers:
    ax.bar_label(i,fmt="%.2f")
ax.set_xticklabels(US_upper_50K_percentage.index,rotation=45);

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
# Your Code is Here
US_private_upper_50K=df.loc[(df.native_country == "United-States")& (df.salary== ">50K")&(df.workclass == "Private")]

# %%
US_private_upper_50K_percentage =US_private_upper_50K.occupation.value_counts(normalize=True)*100
US_private_upper_50K_percentage
# Out:
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
# Your Code is Here
fig,ax = plt.subplots(figsize=(12,6))
sns.barplot(x=US_private_upper_50K_percentage.index,y=US_private_upper_50K_percentage.values)
for i in ax.containers:
    ax.bar_label(i,fmt="%.2f")
ax.set_xticklabels(US_private_upper_50K_percentage.index,rotation=90);

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
# Your Code is Here

df.race.value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
# Your Code is Here
Asian_upper_50K =df.loc[(df.race == "Asian-Pac-Islander")& (df.salary== ">50K")]
Asian_upper_50K
# Out:
#        age         workclass  fnlwgt     education  education_num  \
# 11      30         State-gov  141297     Bachelors         13.000
# 14      40           Private  121772     Assoc-voc            NaN
# 27      54                 ?  180211  Some-college         10.000
# 139     49           Private   81973  Some-college         10.000
# 255     42  Self-emp-not-inc  303044       HS-grad          9.000
# ...    ...               ...     ...           ...            ...
# 32203   51       Federal-gov  223206     Doctorate         16.000
# 32254   31           Private  251659  Some-college         10.000
# 32370   53  Self-emp-not-inc  137547   Prof-school         15.000
# 32457   33           Private  139057       Masters         14.000
# 32533   54           Private  337992     Bachelors         13.000
#
#            marital_status       occupation   relationship                race  \
# 11     Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
# ...

# %%
Asian_upper_50K_percentage =Asian_upper_50K.education.value_counts(normalize=True)*100
Asian_upper_50K_percentage
# Out:
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
fig,ax= plt.subplots(figsize=(12,6))
sns.barplot(x=Asian_upper_50K_percentage.index,y=Asian_upper_50K_percentage.values)
for i in ax.containers:
    ax.bar_label(i,fmt="%.2f")
ax.set_xticklabels(Asian_upper_50K_percentage.index,rotation=90);

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
# Your Code is Here

Asian_Bachelors_upper_50K=df.loc[(df.race == "Asian-Pac-Islander")& (df.salary== ">50K")&(df.education== "Bachelors")]
Asian_Bachelors_upper_50K
# Out:
#        age         workclass  fnlwgt  education  education_num  \
# 11      30         State-gov  141297  Bachelors         13.000
# 873     51  Self-emp-not-inc  160724  Bachelors         13.000
# 968     48           Private  164966  Bachelors         13.000
# 1348    36           Private  153078  Bachelors         13.000
# 1975    40           Private  121956  Bachelors         13.000
# ...    ...               ...     ...        ...            ...
# 31272   39           Private  271521  Bachelors         13.000
# 31327   38         State-gov  125499  Bachelors         13.000
# 31491   39           Private  139012  Bachelors         13.000
# 31673   41           Private  167106  Bachelors         13.000
# 32533   54           Private  337992  Bachelors         13.000
#
#               marital_status       occupation   relationship  \
# 11        Married-civ-spouse   Prof-specialty        Husband
# 873       Married-civ-spouse            Sales        Husband
# ...

# %%
Asian_Bachelors_upper_50K_percentage=Asian_Bachelors_upper_50K.occupation.value_counts(normalize=True)*100
Asian_Bachelors_upper_50K_percentage
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
fig,ax= plt.subplots(figsize=(12,6))
sns.barplot(x=Asian_Bachelors_upper_50K_percentage.index,y=Asian_Bachelors_upper_50K_percentage.values)
for i in ax.containers:
    ax.bar_label(i,fmt="%.2f")
ax.set_xticklabels(Asian_Bachelors_upper_50K_percentage.index,rotation=90);

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
df.head(1)
# Out:
#    age  workclass  fnlwgt  education  education_num marital_status  \
# 0   39  State-gov   77516  Bachelors         13.000  Never-married
#
#      occupation   relationship   race   sex  capital-gain  capital_loss  \
# 0  Adm-clerical  Not-in-family  White  Male          2174             0
#
#    hours_per_week native_country salary education_summary  \
# 0              40  United-States  <=50K             hight
#
#   native_country_summary
# 0                     US

# %%
g = sns.catplot(x="education_summary",
            y="hours_per_week",
            data=df,
            kind="bar",
            hue="sex",
            ci= None,
            col="marital_status_summary",
            row="native_country_summary",
            palette= ["pink","lightskyblue"],
            
               );

g.fig.set_size_inches(15, 8)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('Working Hours Per Week by Sex for Education, Native Country, Marital Status ')

ax1 = g.facet_axis(0,0)
ax2 = g.facet_axis(0,1)
ax3 = g.facet_axis(1,0)
ax4 = g.facet_axis(1,1)


for i in ax1.containers:
         ax1.bar_label(i,fmt="%.2f")
for i in ax2.containers:
         ax2.bar_label(i,fmt="%.2f")
for i in ax3.containers:
         ax3.bar_label(i,fmt="%.2f")        
for i in ax4.containers:
         ax4.bar_label(i,fmt="%.2f")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Internet-Pc\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Internet-Pc\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Internet-Pc\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'marital_status_summary'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/G5KY8nf/93.png)

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:white; background-color:#47AC34" data-toggle="popover">Content</a>

# %%
# Your Code is Here

df.education_num.value_counts()
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   sex                     32537 non-null  object
#  10  capital-gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
# ...

# %%
# Drop the columns of "education", "education_num", "relationship", "marital_status", "native_country" permanently

# Your Code is Here

df.drop(columns=["education","education_num","relationship","marital_status","native_country"],inplace=True)

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:white; background-color:#47AC34" data-toggle="popover">Content</a>

# %% [markdown]
# **Check the missing values for all features basically**

# %%
# Your Code is Here

df.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital-gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# **1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.**
#
# **2. Decide if drop these "Unknown" string values or not**

# %%
# Your Code is Here
df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here

df.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here
df.replace(to_replace="?",value='Unknown',inplace=True)
df.loc[(df.workclass=="Unknown")|(df.workclass== "Never-worked")]["workclass"].value_counts()
# Out:
# Unknown         1836
# Never-worked       7
# Name: workclass, dtype: int64

# %%
df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital-gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# native_country_summary    0
# dtype: int64

# %%
# Replace "Unknown" values with NaN using numpy library

# Your Code is Here

df.replace(to_replace="Unknown",value=np.nan,inplace=True)

# %%
# Your Code is Here

df.isnull().sum()
# Out:
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# sex                          0
# capital-gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# native_country_summary       0
# dtype: int64

# %%
# Drop missing values in df permanently

# Your Code is Here
df.dropna(inplace=True)

# %%
# Your Code is Here
df.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital-gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# native_country_summary    0
# dtype: int64

# %%
# Your Code is Here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   sex                     30694 non-null  object
#  6   capital-gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 3.0+ MB

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:white; background-color:#47AC34" data-toggle="popover">Content</a>

# %% [markdown]
# ### Boxplot and Histplot for all numeric features
#
# **Plot boxplots for each numeric features at the same figure as subplots**

# %%
# Your Code is Here
df.boxplot(figsize=(12,6));

# %%
# Your Code is Here
fig,ax = plt.subplots(nrows=2,ncols=3,figsize=(18,6))

sns.boxplot(ax=ax[0, 0], data=df, x='age')
sns.boxplot(ax=ax[0, 1], data=df, x='fnlwgt')
sns.boxplot(ax=ax[0, 2], data=df, x='capital-gain')
sns.boxplot(ax=ax[1, 0], data=df, x='capital_loss')
sns.boxplot(ax=ax[1, 1], data=df, x='hours_per_week')

ax[1,2].axis("off");

# %% [markdown]
# **Plot both boxplots and histograms for each numeric features at the same figure as subplots**

# %%
# Your Code is Here
fig,ax = plt.subplots(nrows=5,ncols=2,figsize=(18,18))

sns.boxplot(ax=ax[0, 0], data=df, x='age')
sns.histplot(ax=ax[0, 1], data=df, x='age')
sns.boxplot(ax=ax[1, 0], data=df, x='fnlwgt')
sns.histplot(ax=ax[1, 1], data=df, x='fnlwgt')
sns.boxplot(ax=ax[2, 0], data=df, x='capital-gain')
sns.histplot(ax=ax[2, 1], data=df, x='capital-gain')
sns.boxplot(ax=ax[3, 0], data=df, x='capital_loss')
sns.histplot(ax=ax[3, 1], data=df, x='capital_loss')
sns.boxplot(ax=ax[4, 0], data=df, x='hours_per_week')
sns.histplot(ax=ax[4, 1], data=df, x='hours_per_week');

# %% [markdown]
# **Check the statistical values for all numeric features**

# %%
# Your Code is Here
df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            30694.000     38.448     13.115    17.000     28.000
# fnlwgt         30694.000 189848.229 105465.126 13769.000 117828.500
# capital-gain   30694.000   1106.902   7500.730     0.000      0.000
# capital_loss   30694.000     88.980    405.808     0.000      0.000
# hours_per_week 30694.000     40.953     11.984     1.000     40.000
#
#                       50%        75%         max
# age                37.000     47.000      90.000
# fnlwgt         178513.500 237293.750 1484705.000
# capital-gain        0.000      0.000   99999.000
# capital_loss        0.000      0.000    4356.000
# hours_per_week     40.000     45.000      99.000

# %% [markdown]
# **1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.**
#
# **2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.**

# %% [markdown]
# ### age

# %%
# Your Code is Here
fig,ax = plt.subplots(ncols=2,figsize=(12,6))

sns.boxplot(ax=ax[0], data=df, y='age')
sns.histplot(ax=ax[1], data=df, x='age');

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here
Q1 = df.age.quantile(0.25)
Q3 =df.age.quantile(0.75)
IQR = Q3-Q1
Q1,Q3,IQR
# Out:
# (28.0, 47.0, 19.0)

# %%
# Find lower and upper limit using IQR

# Your Code is Here

lower_lim_age= Q1 - 1.5*IQR
upper_lim_age= Q3 + 1.5*IQR

lower_lim_age,upper_lim_age
# Out:
# (-0.5, 75.5)

# %%
# Your Code is Here
lower_lim_age= 0
upper_lim_age= Q3 + 1.5*IQR
lower_lim_age,upper_lim_age
# Out:
# (0, 75.5)

# %%
df.age.value_counts().tail(14)
# Out:
# 90    35
# 75    34
# 76    30
# 77    20
# 80    16
# 79    15
# 78    14
# 81    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
# Define the observations whose age is greater than upper limit and sort these observations by age in descending order

# Your Code is Here
df.loc[(df.age >= upper_lim_age)].sort_values(by=["age"],ascending=False)
# Out:
#        age         workclass  fnlwgt       occupation                race  \
# 8806    90           Private   87372   Prof-specialty               White
# 14159   90         Local-gov  187749     Adm-clerical  Asian-Pac-Islander
# 28463   90       Federal-gov  195433     Craft-repair               White
# 12975   90           Private  250832  Exec-managerial               White
# 11996   90           Private   40388  Exec-managerial               White
# ...    ...               ...     ...              ...                 ...
# 15102   76         Local-gov  169133     Adm-clerical               White
# 19085   76           Private  125784  Exec-managerial               White
# 23515   76           Private  142535     Adm-clerical               White
# 8240    76  Self-emp-not-inc  225964            Sales               White
# 23354   76           Private  199949     Adm-clerical               White
#
#           sex  capital-gain  capital_loss  hours_per_week salary  \
# ...

# %% [markdown]
# ### hours_per_week

# %%
# Your Code is Here
fig,ax = plt.subplots(ncols=2,figsize=(12,6))

sns.boxplot(ax=ax[0], data=df, y='hours_per_week')
sns.histplot(ax=ax[1], data=df, x='hours_per_week',bins=10);

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here
Q1 = df.hours_per_week.quantile(0.25)
Q3 =df.hours_per_week.quantile(0.75)
IQR = Q3-Q1
Q1,Q3,IQR
# Out:
# (40.0, 45.0, 5.0)

# %%
# Find the lower and upper limit using IQR

# Your Code is Here
lower_lim_hours_per_week= Q1 - 1.5*IQR
upper_lim_hours_per_week= Q3 + 1.5*IQR

lower_lim_hours_per_week,upper_lim_hours_per_week
# Out:
# (32.5, 52.5)

# %%
# Your Code is Here
(df.loc[(df.hours_per_week >= upper_lim_hours_per_week)].hours_per_week.value_counts()).sort_index(ascending=False)
# Out:
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
# Define the observations where  hours per week are greater than upper limit and 
# sort these observations by hours per week in descending order

# Your Code is Here
df.loc[(df.hours_per_week >= upper_lim_hours_per_week)].sort_values(by=["hours_per_week"],ascending=False)
# Out:
#        age         workclass  fnlwgt        occupation   race     sex  \
# 25986   44         Local-gov  212665   Protective-serv  Black    Male
# 19529   38           Private   66326  Transport-moving  White    Male
# 8796    39           Private   70995  Transport-moving  White    Male
# 15534   29           Private  167716     Other-service  White  Female
# 22313   26  Self-emp-not-inc  258306   Farming-fishing  White    Male
# ...    ...               ...     ...               ...    ...     ...
# 1138    27           Private  138705      Craft-repair  White    Male
# 23244   58           Private  248739   Farming-fishing  White    Male
# 28858   62           Private  123411  Transport-moving  White    Male
# 18417   24           Private  117167     Other-service  White  Female
# 31622   61  Self-emp-not-inc  268831             Sales  White    Male
#
#        capital-gain  capital_loss  hours_per_week salary education_summary  \
# ...

# %%
# Your Code is Here
(df.loc[(df.hours_per_week < lower_lim_hours_per_week)].hours_per_week.value_counts()).sort_index(ascending=True)
# Out:
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %%
# Your Code is Here

df.loc[(df.hours_per_week < lower_lim_hours_per_week)].groupby("salary")["hours_per_week"].describe()
# Out:
#           count   mean   std   min    25%    50%    75%    max
# salary
# <=50K  4372.000 21.548 7.343 1.000 16.000 20.000 30.000 32.000
# >50K    322.000 22.028 7.813 1.000 18.000 24.000 30.000 32.000

# %%
# Your Code is Here

df.loc[(df.hours_per_week < lower_lim_hours_per_week) ].groupby("salary")["age"].describe()
# Out:
#           count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  4372.000 34.052 17.730 17.000 20.000 26.000 45.000 90.000
# >50K    322.000 49.484 13.894 22.000 39.000 48.000 60.000 90.000

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %%
# Create a condition according to your domain knowledge on age stated above and 
# sort the observations meeting this condition by age in ascending order

# Your Code is Here
age_17_to_80 =df.loc[(df.age > 80)| (df.age < 17)].sort_values("age",ascending=False)
age_17_to_80
# Out:
#        age     workclass  fnlwgt       occupation   race     sex  \
# 222     90       Private   51744    Other-service  Black    Male
# 18832   90       Private  115306  Exec-managerial  White  Female
# 10545   90       Private  175491     Craft-repair  White    Male
# 11512   90       Private   87285    Other-service  White  Female
# 11996   90       Private   40388  Exec-managerial  White    Male
# ...    ...           ...     ...              ...    ...     ...
# 19045   81     State-gov  132204    Other-service  White  Female
# 6748    81       Private  122651            Sales  White    Male
# 2906    81       Private  114670  Priv-house-serv  Black  Female
# 21501   81       Private  177408  Exec-managerial  White    Male
# 19495   81  Self-emp-inc  247232  Exec-managerial  White  Female
#
#        capital-gain  capital_loss  hours_per_week salary education_summary  \
# 222               0          2206              40  <=50K            medium
# ...

# %%
# Find the shape of the dataframe created by the condition defined above for age 

# Your Code is Here
age_17_to_80.shape
# Out:
# (76, 12)

# %%
# Assign the indices of the rows defined in accordance with condition above for age

# Your Code is Here
age_17_to_80.index
# Out:
# Int64Index([  222, 18832, 10545, 11512, 11996, 12975, 14159, 15892, 18277,
#             18413, 18725, 19212,  8973, 19489, 19747, 20610, 22220, 24043,
#             28463, 31030, 32277, 32367, 10210, 15356,  5370,  4070,  1040,
#              6232,  1935,  2303,  5272,  6624,  2891,  5406,  8806,  1168,
#             22895, 21835, 24027, 20463,  8381, 32459, 26731, 27795,  9471,
#              6214, 14711, 11238,  7720, 15662,  7481, 24395, 23459, 19172,
#             16302, 14756,  8431, 20421, 22481, 31855, 13696, 24280,  4834,
#             29594, 28948, 12830,   918, 13295, 24560,  3537, 13928, 19045,
#              6748,  2906, 21501, 19495],
#            dtype='int64')

# %%
# Drop these indices defined above for age

# Your Code is Here
df.drop(age_17_to_80.index,inplace=True)

# %%
# Create a condition according to your domain knowledge on hours per week stated above and 
# sort the observations meeting this condition by hours per week in descending order

# Your Code is Here
hpw_7_to_70=df.loc[(df.hours_per_week > 70)  | (df.hours_per_week < 7)].sort_values(by="hours_per_week",ascending=False)
hpw_7_to_70
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 22216   45           Private   54260      Craft-repair               White
# 5432    44           Private   83508    Prof-specialty               White
# 19053   27           Private   40295  Transport-moving               White
# 19141   59           Private  106748     Other-service               White
# 19399   39      Self-emp-inc  163057      Craft-repair               White
# ...    ...               ...     ...               ...                 ...
# 20909   77  Self-emp-not-inc   71676      Adm-clerical               White
# 25078   74           Private  260669     Other-service               White
# 19750   23           Private   72887      Craft-repair  Asian-Pac-Islander
# 189     58         State-gov  109567    Prof-specialty               White
# 24284   57  Self-emp-not-inc   56480   Exec-managerial               White
#
#           sex  capital-gain  capital_loss  hours_per_week salary  \
# ...

# %%
# Find the shape of the dataframe created by the condition defined above for hours per week 

# Your Code is Here
hpw_7_to_70.shape
# Out:
# (621, 12)

# %%
# Assign the indices of the rows defined in accordance with condition above for hours per week

# Your Code is Here
hpw_7_to_70.index
# Out:
# Int64Index([22216,  5432, 19053, 19141, 19399, 19529, 19731, 19997, 20036,
#             21056,
#             ...
#              6180, 29867,  1036, 11451, 22960, 20909, 25078, 19750,   189,
#             24284],
#            dtype='int64', length=621)

# %%
# Drop these indices defined above for hours per week

# Your Code is Here
df.drop(hpw_7_to_70.index,inplace=True)

# %%
# Create a condition according to your domain knowledge on both age and hours per week stated above 

# Your Code is Here
df.hours_per_week.value_counts()
# Out:
# 40    14490
# 50     2754
# 45     1788
# 60     1439
# 35     1199
#       ...
# 29        6
# 31        5
# 59        5
# 67        4
# 61        2
# Name: hours_per_week, Length: 63, dtype: int64

# %%
# Find the shape of the dataframe created by the condition defined above for both age and hours per week


# Your Code is Here
ageupper60_hpwupper60=df.loc[(df.age > 60)&(df.hours_per_week > 60)]
ageupper60_hpwupper60
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 1541    62           Private  162245    Prof-specialty               White
# 2154    75           Private  101887   Priv-house-serv               White
# 2184    63      Self-emp-inc   54052             Sales               White
# 2665    70           Private   94692             Sales               White
# 3101    65      Self-emp-inc   81413   Farming-fishing               White
# 5417    67           Private  197816             Sales               White
# 6826    68           Private  284763  Transport-moving               White
# 8066    61  Self-emp-not-inc  133969             Sales  Asian-Pac-Islander
# 9646    62  Self-emp-not-inc   26911     Other-service               White
# 12624   63      Self-emp-inc  110890    Prof-specialty               White
# 16634   62  Self-emp-not-inc  115176   Farming-fishing               White
# ...

# %%
ageupper60_hpwupper60.shape
# Out:
# (23, 12)

# %%
# Assign the indices of the rows defined in accordance with condition above for both age and hours per week

# Your Code is Here
ageupper60_hpwupper60.index
# Out:
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 23399, 23585, 24903, 25910,
#             26625, 27721, 28294, 31342, 32192],
#            dtype='int64')

# %%
# Drop these indices defined above for both age and hours per week

# Your Code is Here
df.drop(ageupper60_hpwupper60.index,inplace=True)

# %%
# What is new shape of dataframe now

# Your Code is Here
df.shape
# Out:
# (29974, 12)

# %%
# Reset the indices and take the head of DataFrame now

# Your Code is Here
df.head()
# Out:
#    age         workclass  fnlwgt         occupation   race     sex  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
#
#    capital-gain  capital_loss  hours_per_week salary education_summary  \
# 0          2174             0              40  <=50K             hight
# 1             0             0              13  <=50K             hight
# 2             0             0              40  <=50K            medium
# 3             0             0              40  <=50K               low
# 4             0             0              40  <=50K             hight
#
#   native_country_summary
# 0                     US
# 1                     US
# 2                     US
# 3                     US
# ...

# %% [markdown]
# ## <p style="background-color:#47AC34; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:FFF9ED; background-color:#47AC34" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# **Convert target feature (salary) to numeric (0 and 1) by using map function**

# %%
# Your Code is Here
df.salary= df.salary.map({"<=50K":0,">50K":1})
df.salary
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: salary, Length: 29974, dtype: int64

# %%
# Your Code is Here

df.salary.value_counts()
# Out:
# 0    22524
# 1     7450
# Name: salary, dtype: int64

# %% [markdown]
# **Convert all features to numeric by using get_dummies function**

# %%
# Your Code is Here

pd.get_dummies(df,drop_first=True)
# Out:
#        age  fnlwgt  capital-gain  capital_loss  hours_per_week  salary  \
# 0       39   77516          2174             0              40       0
# 1       50   83311             0             0              13       0
# 2       38  215646             0             0              40       0
# 3       53  234721             0             0              40       0
# 4       28  338409             0             0              40       0
# ...    ...     ...           ...           ...             ...     ...
# 32556   27  257302             0             0              38       0
# 32557   40  154374             0             0              40       1
# 32558   58  151910             0             0              40       0
# 32559   22  201490             0             0              20       0
# 32560   52  287927         15024             0              40       1
#
#        workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# ...

# %%
# What's the shape of dataframe

# Your Code is Here
df.shape
# Out:
# (29974, 12)

# %%
# What's the shape of dataframe created by dummy operation

# Your Code is Here

pd.get_dummies(df,drop_first=True).shape
# Out:
# (29974, 33)

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %%
# Your Code is Here
df_corr =pd.get_dummies(df,drop_first=True).corr()
df_corr
# Out:
#                                 age  fnlwgt  capital-gain  capital_loss  \
# age                           1.000  -0.074         0.082         0.059
# fnlwgt                       -0.074   1.000        -0.002        -0.011
# capital-gain                  0.082  -0.002         1.000        -0.032
# capital_loss                  0.059  -0.011        -0.032         1.000
# hours_per_week                0.119  -0.019         0.086         0.060
# salary                        0.253  -0.010         0.222         0.152
# workclass_Local-gov           0.070  -0.004        -0.010         0.015
# workclass_Private            -0.211   0.045        -0.045        -0.039
# workclass_Self-emp-inc        0.111  -0.025         0.093         0.031
# workclass_Self-emp-not-inc    0.146  -0.037         0.033         0.023
# workclass_State-gov           0.020  -0.012        -0.013        -0.002
# workclass_Without-pay         0.016  -0.003        -0.002        -0.005
# ...

# %%
# Your Code is Here
fig,ax=plt.subplots(figsize=(18,18))
sns.heatmap(df_corr,annot=True,cmap="YlGnBu");

# %%
# Your Code is Here
df_corr_salary = df_corr[["salary"]].sort_values("salary",ascending=False)[1::]
df_corr_salary
# Out:
#                               salary
# age                            0.253
# hours_per_week                 0.247
# capital-gain                   0.222
# sex_Male                       0.216
# occupation_Exec-managerial     0.215
# occupation_Prof-specialty      0.185
# capital_loss                   0.152
# workclass_Self-emp-inc         0.138
# race_White                     0.086
# native_country_summary_US      0.035
# workclass_Self-emp-not-inc     0.030
# workclass_Local-gov            0.029
# occupation_Protective-serv     0.026
# occupation_Tech-support        0.023
# occupation_Sales               0.015
# race_Asian-Pac-Islander        0.012
# workclass_State-gov            0.011
# occupation_Armed-Forces       -0.006
# fnlwgt                        -0.010
# workclass_Without-pay         -0.012
# occupation_Craft-repair       -0.021
# occupation_Transport-moving   -0.029
# race_Other                    -0.032
# occupation_Priv-house-serv    -0.038
# ...

# %%
# Your Code is Here
fig,ax=plt.subplots(figsize=(6,18))
sns.heatmap(df_corr_salary,annot=True,cmap="YlGnBu",fmt='.3g');

# %%
# Your Code is Here
df_corr_salary.plot.barh();

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:white; background-color:#47AC34" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#47AC34; font-family:arial; color:white; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://techproeducation.com/wp-content/uploads/2022/01/Calisma-Yuzeyi-1-kopya-5-1-768x126.png" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#47AC34; font-family:arial; color:white; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
